# %%
import pandas as pd 
import numpy as np 
import re 
from sklearn.model_selection import train_test_split 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequnential 
from tensorflow.keras.layers import SimpleRNN,Dense,Embedding
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 from tensorflow.keras.preprocessing.text import Tokenizer
#       6 from tensorflow.keras.preprocessing.sequence import pad_sequences
# ----> 7 from tensorflow.keras.models import Sequnential
#       8 from tensorflow.keras.layers import SimpleRNN,Dense,Embedding
#
# ImportError: cannot import name 'Sequnential' from 'tensorflow.keras.models' (C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\keras\_tf_keras\keras\models\__init__.py)
